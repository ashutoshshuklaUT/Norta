# %%
import yaml
import json
import pandas as pd
from utils import prepare_input
from main_model import two_stage_model

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Reading solved models data

# %%
path = "/home1/07346/ashukla/Norta/TwoStageModel/output/sm_16/"
with open(path + "model_params.json") as file:
    model_params = json.load(file)

# %%
model_params["path_to_input"] = "16_Scenario/"
model_params["path_to_output"] = "Error_Path"
model_params["mit_coarse"] = 1

# %%
model_params["input1"], model_params["input2"] = prepare_input(model_params["path_to_input"])

# %%
base_model = two_stage_model(model_params)        
base_model.model.update()

budget_vector = [0,10,20,30,40,50,60,70,80]
# Out:
# Set parameter TokenServer to value "license02.tacc.utexas.edu"

# %%
hardening_decisions = {}
for budget in budget_vector:
    hardening = []
    sol_path = path + str(budget) + "M_solution.sol"
    base_model.model.read(sol_path)
    base_model.model.update()
    for sub_id in base_model.unique_substations:
        temp = round(base_model.model.getVarByName('x[' +  str(sub_id) + ']').Start)
        hardening.append(temp)
    hardening_decisions[budget] = hardening
df = pd.DataFrame(hardening_decisions)
df.index = base_model.unique_substations

df = df[df.sum(axis=1) > 0]

# %% [markdown]
# ### Reading norta scenarios and building model from that

# %%
n_scenario = 16
objective_value = {}
budget_vector = [0,10,20,30,40,50,60,70,80]
#budget_vector = [10]

for scenario_id in range(50):
    objective_value[scenario_id] = {}
    
    dir_name = 'norta_sm_' + str(n_scenario) + "_" + str(scenario_id) +'/'
    with open(r'config.yaml') as file:
        model_params = yaml.load(file, Loader=yaml.FullLoader)

    model_params["path_to_input"] = "16_Scenario/"
    model_params["path_to_output"] = "Error_Path"
    
    model_params["mip_gap"] = 0
    
    
    
    model_params["input1"], model_params["input2"] = prepare_input(model_params["path_to_input"])

    for column_id in model_params["input1"].columns:
        if "max_flood_level" in column_id:
            model_params["input1"][column_id] = 0

    norta_scenario = pd.read_csv("../scenarios/" + str(scenario_id) + "/" + "Final_Input1.csv", index_col="Unnamed: 0")
    set_of_flooded_substations = norta_scenario.columns
    meow_maps = list(norta_scenario.index)

    for row_id in range(model_params["input1"].shape[0]):
        substation_ = model_params["input1"].iloc[row_id,2]
        if str(substation_) in set_of_flooded_substations:
            busnum = model_params["input1"].index[row_id]
            model_params["input1"].loc[busnum,meow_maps] = list(norta_scenario[str(substation_)])

    base_model = two_stage_model(model_params)
    
    
    for budget in budget_vector:
        print(scenario_id, budget)
        base_model.budget_ref.rhs = budget*1e6    
        temp_constraint =  base_model.model.addConstrs((base_model.x[substation] == df.loc[substation, budget]) 
                                                   for substation in list(df.index))
                    
        base_model.model.setParam("LogFile", model_params["path_to_output"] + str(budget) + "M")
        base_model.model.setParam("MIPGap", model_params["mip_gap"])
        base_model.model.setParam("TimeLimit", model_params["time_limit"])
        base_model.model.setParam("Method", model_params["solver_method"])
        base_model.model.optimize()
        objective_value[scenario_id][budget] = base_model.model.ObjVal/10
        base_model.model.remove(temp_constraint)
        print("\n\n\n\n")
# Out:
# 0 0
# Set parameter LogFile to value "Error_Path0M"
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 32400
# Set parameter Method to value 2
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x2216eb9e
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 2e+04]
# Presolve removed 210897 rows and 76724 columns
# Presolve time: 2.19s
# Presolved: 882 rows, 1184 columns, 4022 nonzeros
# Variable types: 1036 continuous, 148 integer (148 binary)
# Found heuristic solution: objective 65.5921693
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.685e+03
#  Factor NZ  : 2.126e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.015e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.88103961e+03 -8.21153673e+03  1.57e+02 2.05e-01  3.52e+01     2s
#    1  -3.20854123e+01 -4.38036948e+03  7.09e+00 3.25e-02  3.42e+00     2s
#    2   4.68403622e+01 -5.05713019e+02  6.48e-01 7.41e-05  3.29e-01     2s
#    3   5.17661668e+01 -1.07092567e+01  5.53e-02 1.11e-15  3.26e-02     2s
#    4   4.71812375e+01  2.96328143e+01  1.36e-03 1.33e-15  8.65e-03     2s
#    5   4.45308360e+01  3.98154301e+01  8.73e-05 4.44e-16  2.32e-03     2s
#    6   4.39077086e+01  4.22616976e+01  2.24e-05 2.22e-16  8.09e-04     2s
#    7   4.37301575e+01  4.30021777e+01  6.50e-06 4.44e-16  3.58e-04     2s
#    8   4.36876926e+01  4.34166795e+01  3.83e-06 2.22e-16  1.33e-04     2s
#    9   4.36573132e+01  4.35274272e+01  1.24e-06 2.22e-16  6.38e-05     2s
#   10   4.36421644e+01  4.36203980e+01  5.11e-07 4.44e-16  1.07e-05     2s
#   11   4.36324600e+01  4.36312921e+01  2.73e-10 2.22e-16  5.74e-07     2s
#   12   4.36322248e+01  4.36322230e+01  2.82e-10 2.22e-16  8.92e-10     2s
#   13   4.36322242e+01  4.36322242e+01  1.10e-09 4.44e-16  8.96e-13     2s
#
# Barrier solved model in 13 iterations and 2.33 seconds (1.71 work units)
# Optimal objective 4.36322242e+01
#
#
# Root relaxation: objective 4.363222e+01, 21 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   43.63222    0    3   65.59217   43.63222  33.5%     -    2s
# H    0     0                      43.6837084   43.63222  0.12%     -    2s
# H    0     0                      43.6322333   43.63222  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (21 simplex iterations) in 2.39 seconds (1.73 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 43.6322 43.6837 65.5922
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.363223326705e+01, best bound 4.363223326705e+01, gap 0.0000%
#
#
#
#
#
# 0 10
# Set parameter LogFile to value "Error_Path10M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x6cd886c6
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 1e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R211792 by 4.000000000
#
# Presolve removed 210845 rows and 76668 columns
# Presolve time: 2.70s
# Presolved: 934 rows, 1240 columns, 4184 nonzeros
# Variable types: 1079 continuous, 161 integer (161 binary)
# Found heuristic solution: objective 43.8902249
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.839e+03
#  Factor NZ  : 2.271e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.116e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.99703246e+03 -9.11853834e+03  1.57e+02 2.05e-01  3.57e+01     3s
#    1  -5.96641822e+01 -4.70168140e+03  7.14e+00 3.20e-02  3.48e+00     3s
#    2   2.49968136e+01 -4.90152907e+02  5.95e-01 5.89e-05  2.94e-01     3s
#    3   2.89318933e+01 -2.31185452e+01  3.78e-02 1.33e-15  2.57e-02     3s
#    4   2.38212483e+01  1.07630284e+01  8.91e-04 6.66e-16  6.17e-03     3s
#    5   2.21175303e+01  1.90320252e+01  2.20e-04 2.22e-16  1.46e-03     3s
#    6   2.14918674e+01  2.07987922e+01  4.95e-05 4.44e-16  3.27e-04     3s
#    7   2.13786302e+01  2.10850820e+01  2.33e-05 4.44e-16  1.39e-04     3s
#    8   2.13603611e+01  2.11860416e+01  1.95e-05 1.11e-16  8.24e-05     3s
#    9   2.13270851e+01  2.12136337e+01  1.27e-05 2.22e-16  5.36e-05     3s
#   10   2.12913379e+01  2.12559207e+01  4.99e-06 4.44e-16  1.68e-05     3s
#   11   2.12699191e+01  2.12665560e+01  3.00e-09 2.22e-16  1.59e-06     3s
#   12   2.12673798e+01  2.12673168e+01  3.02e-10 2.22e-16  2.97e-08     3s
#   13   2.12673538e+01  2.12673536e+01  3.36e-08 4.44e-16  1.23e-10     3s
#   14   2.12673536e+01  2.12673536e+01  8.47e-11 2.22e-16  1.23e-13     3s
#
# Barrier solved model in 14 iterations and 2.91 seconds (2.01 work units)
# Optimal objective 2.12673536e+01
#
#
# Root relaxation: objective 2.126735e+01, 16 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   21.26735    0    3   43.89022   21.26735  51.5%     -    2s
# H    0     0                      21.4222721   21.26735  0.72%     -    2s
# H    0     0                      21.2681973   21.26735  0.00%     -    2s
# H    0     0                      21.2675091   21.26735  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 2
#
# Explored 1 nodes (16 simplex iterations) in 3.01 seconds (2.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 21.2675 21.2682 21.4223 43.8902
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.126750911966e+01, best bound 2.126750911966e+01, gap 0.0000%
#
#
#
#
#
# 0 20
# Set parameter LogFile to value "Error_Path20M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x6e64c814
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 2e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R211852 by 7.000000000
#
# Presolve removed 210796 rows and 76612 columns
# Presolve time: 2.29s
# Presolved: 983 rows, 1296 columns, 4335 nonzeros
# Variable types: 1118 continuous, 178 integer (178 binary)
# Found heuristic solution: objective 36.2714079
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.680e+03
#  Factor NZ  : 2.406e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.304e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.11459965e+03 -5.56085685e+03  1.05e+02 8.31e-02  1.67e+01     2s
#    1  -1.78238813e+01 -2.99236660e+03  3.94e+00 8.30e-02  1.90e+00     2s
#    2   1.85449698e+01 -2.91240844e+02  4.77e-01 3.03e-03  1.71e-01     2s
#    3   2.00395366e+01 -2.03081308e+01  4.43e-02 1.61e-04  2.02e-02     2s
#    4   1.48779610e+01  8.47997592e+00  5.30e-04 8.88e-16  3.06e-03     2s
#    5   1.33812870e+01  1.19288067e+01  1.15e-05 2.22e-16  6.93e-04     2s
#    6   1.33186123e+01  1.31294524e+01  4.41e-06 2.22e-16  9.03e-05     2s
#    7   1.32882037e+01  1.32723258e+01  8.73e-08 2.22e-16  7.58e-06     2s
#    8   1.32872855e+01  1.32872665e+01  1.38e-11 2.22e-16  9.07e-09     2s
#    9   1.32872827e+01  1.32872827e+01  1.34e-11 2.22e-16  9.12e-15     2s
#
# Barrier solved model in 9 iterations and 2.48 seconds (1.89 work units)
# Optimal objective 1.32872827e+01
#
#
# Root relaxation: objective 1.328728e+01, 74 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      13.2872827   13.28728  0.00%     -    2s
#
# Explored 1 nodes (74 simplex iterations) in 2.52 seconds (1.90 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 13.2873 36.2714
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.328728271719e+01, best bound 1.328728271719e+01, gap 0.0000%
#
#
#
#
#
# 0 30
# Set parameter LogFile to value "Error_Path30M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x80e596ce
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 3e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R211924 by 1.000000000
#
# Presolve removed 210772 rows and 76581 columns
# Presolve time: 2.52s
# Presolved: 1007 rows, 1327 columns, 4436 nonzeros
# Variable types: 1148 continuous, 179 integer (179 binary)
# Found heuristic solution: objective 31.6406064
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.834e+03
#  Factor NZ  : 2.553e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.427e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.14648913e+03 -5.64420653e+03  1.05e+02 8.33e-02  1.67e+01     3s
#    1  -2.35309549e+01 -3.07575171e+03  3.94e+00 8.31e-02  1.90e+00     3s
#    2   1.37431379e+01 -3.07184887e+02  4.75e-01 3.09e-03  1.72e-01     3s
#    3   1.52743641e+01 -2.54552970e+01  4.37e-02 1.55e-04  1.98e-02     3s
#    4   9.90543818e+00  4.67233117e+00  4.23e-05 3.33e-16  2.42e-03     3s
#    5   8.56007380e+00  7.58932443e+00  4.71e-06 2.22e-16  4.50e-04     3s
#    6   8.38652435e+00  8.35570235e+00  2.81e-08 2.22e-16  1.43e-05     3s
#    7   8.38382854e+00  8.38370178e+00  8.22e-11 2.22e-16  5.87e-08     3s
#    8   8.38380688e+00  8.38380687e+00  6.48e-12 2.22e-16  1.11e-13     3s
#
# Barrier solved model in 8 iterations and 2.71 seconds (2.06 work units)
# Optimal objective 8.38380688e+00
#
#
# Root relaxation: objective 8.383807e+00, 75 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.3838069    8.38381  0.00%     -    2s
#
# Explored 1 nodes (75 simplex iterations) in 2.75 seconds (2.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 8.38381 31.6406
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.383806875001e+00, best bound 8.383806875001e+00, gap 0.0000%
#
#
#
#
#
# 0 40
# Set parameter LogFile to value "Error_Path40M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x1bfe24b5
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 4e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R211996 by 1.000000000
#
# Presolve removed 210748 rows and 76553 columns
# Presolve time: 2.52s
# Presolved: 1031 rows, 1355 columns, 4517 nonzeros
# Variable types: 1171 continuous, 184 integer (184 binary)
# Found heuristic solution: objective 28.3466727
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.895e+03
#  Factor NZ  : 2.709e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.601e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.18939318e+02 -5.78776695e+03  6.50e+01 8.35e-02  1.14e+01     3s
#    1  -1.93577531e+01 -2.16157228e+03  3.20e+00 5.22e-02  1.33e+00     3s
#    2   1.17723313e+01 -2.26862915e+02  3.16e-01 1.37e-03  1.23e-01     3s
#    3   1.08374784e+01 -2.92455119e+01  1.57e-02 1.32e-04  1.86e-02     3s
#    4   6.11681314e+00  1.02946601e+00  1.98e-05 4.44e-15  2.32e-03     3s
#    5   4.93060017e+00  4.62412566e+00  2.64e-07 2.22e-16  1.40e-04     3s
#    6   4.89726320e+00  4.89513897e+00  1.78e-11 4.44e-16  9.68e-07     3s
#    7   4.89701104e+00  4.89700786e+00  6.98e-12 2.22e-16  1.45e-09     3s
#    8   4.89701063e+00  4.89701062e+00  6.93e-12 4.44e-16  1.45e-15     3s
#
# Barrier solved model in 8 iterations and 2.71 seconds (2.04 work units)
# Optimal objective 4.89701063e+00
#
#
# Root relaxation: objective 4.897011e+00, 76 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.89701    0    1   28.34667    4.89701  82.7%     -    2s
# H    0     0                       4.8970106    4.89701  0.00%     -    2s
#      0     0    4.89701    0    1    4.89701    4.89701  0.00%     -    2s
#
# Explored 1 nodes (76 simplex iterations) in 2.75 seconds (2.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 4.89701 28.3467
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.897010625001e+00, best bound 4.897010625001e+00, gap 0.0000%
#
#
#
#
#
# 0 50
# Set parameter LogFile to value "Error_Path50M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x0afd84bb
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 5e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212071 by 1.000000000
#
# Presolve removed 210713 rows and 76508 columns
# Presolve time: 2.60s
# Presolved: 1066 rows, 1400 columns, 4647 nonzeros
# Variable types: 1214 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 26.0048164
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.038e+03
#  Factor NZ  : 2.833e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.725e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.44573105e+02 -6.08159591e+03  6.51e+01 8.35e-02  1.14e+01     3s
#    1  -2.27321794e+01 -2.26614859e+03  3.19e+00 5.19e-02  1.34e+00     3s
#    2   9.20792823e+00 -2.37755842e+02  3.18e-01 1.35e-03  1.22e-01     3s
#    3   8.64408763e+00 -3.06377960e+01  1.52e-02 9.52e-05  1.75e-02     3s
#    4   3.60291689e+00 -1.52077135e+00  1.30e-05 2.22e-16  2.25e-03     3s
#    5   2.43507009e+00  2.16726791e+00  1.85e-07 2.22e-16  1.18e-04     3s
#    6   2.40418070e+00  2.40235594e+00  1.75e-11 2.22e-16  8.01e-07     3s
#    7   2.40396026e+00  2.40395829e+00  5.15e-12 2.22e-16  8.65e-10     3s
#    8   2.40396000e+00  2.40396000e+00  1.12e-11 4.44e-16  8.65e-16     3s
#
# Barrier solved model in 8 iterations and 2.80 seconds (2.11 work units)
# Optimal objective 2.40396000e+00
#
#
# Root relaxation: objective 2.403960e+00, 77 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.40396    0    1   26.00482    2.40396  90.8%     -    2s
# H    0     0                       2.4039600    2.40396  0.00%     -    2s
#      0     0    2.40396    0    1    2.40396    2.40396  0.00%     -    2s
#
# Explored 1 nodes (77 simplex iterations) in 2.84 seconds (2.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 2.40396 26.0048
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.403960000001e+00, best bound 2.403960000001e+00, gap 0.0000%
#
#
#
#
#
# 0 60
# Set parameter LogFile to value "Error_Path60M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0x4b464382
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 6e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212140 by 2.000000000
#
# Presolve removed 210693 rows and 76480 columns
# Presolve time: 2.98s
# Presolved: 1086 rows, 1428 columns, 4742 nonzeros
# Variable types: 1242 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 24.2920008
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.397e+03
#  Factor NZ  : 2.801e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.578e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.34327063e+03 -9.61578519e+03  1.05e+02 1.67e-01  2.52e+01     3s
#    1  -4.21846779e+01 -5.25414085e+03  4.25e+00 1.25e-01  2.96e+00     3s
#    2   7.15478922e+00 -5.59207367e+02  3.93e-01 2.47e-03  2.68e-01     3s
#    3   8.90452833e+00 -5.03489364e+01  1.75e-02 1.27e-04  2.53e-02     3s
#    4   3.06536007e+00 -1.19800872e+01  2.14e-04 6.51e-06  6.33e-03     3s
#    5   8.15775513e-01 -5.05754524e-01  3.90e-08 2.22e-16  5.55e-04     3s
#    6   6.09237696e-01  5.62168590e-01  9.61e-12 2.22e-16  1.98e-05     3s
#    7   6.06913323e-01  6.06231434e-01  1.45e-11 2.22e-16  2.87e-07     3s
#    8   6.06840001e-01  6.06839822e-01  3.90e-12 2.22e-16  7.53e-11     3s
#
# Barrier solved model in 8 iterations and 3.18 seconds (2.30 work units)
# Optimal objective 6.06840001e-01
#
#
# Root relaxation: objective 6.068400e-01, 83 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.6068400    0.60684  0.00%     -    3s
#
# Explored 1 nodes (83 simplex iterations) in 3.22 seconds (2.30 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.60684 24.292
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 6.068400000004e-01, best bound 6.068400000004e-01, gap 0.0000%
#
#
#
#
#
# 0 70
# Set parameter LogFile to value "Error_Path70M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0xfe5ada48
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 7e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212214 by 3.000000000
#
# Presolve removed 210677 rows and 76451 columns
# Presolve time: 3.11s
# Presolved: 1102 rows, 1457 columns, 4839 nonzeros
# Variable types: 1271 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 23.7406833
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.493e+03
#  Factor NZ  : 3.035e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.829e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.38520678e+03 -9.90855162e+03  1.05e+02 1.67e-01  2.52e+01     3s
#    1  -4.42331791e+01 -5.37604237e+03  4.26e+00 1.25e-01  2.95e+00     3s
#    2   6.67323681e+00 -5.57836122e+02  3.82e-01 3.14e-03  2.61e-01     3s
#    3   8.36491027e+00 -5.48076619e+01  1.81e-02 1.84e-04  2.64e-02     3s
#    4   2.56758098e+00 -1.32271755e+01  1.84e-04 1.61e-05  6.48e-03     3s
#    5   2.59529683e-01 -1.14800954e+00  3.33e-08 4.44e-16  5.77e-04     3s
#    6   2.38750744e-02 -7.28730743e-03  1.72e-10 4.44e-16  1.28e-05     3s
#    7   2.08592475e-02  2.04373103e-02  1.98e-11 2.22e-16  1.73e-07     3s
#    8   2.08200000e-02  2.08199988e-02  1.13e-11 4.44e-16  5.20e-13     3s
#
# Barrier solved model in 8 iterations and 3.32 seconds (2.41 work units)
# Optimal objective 2.08200000e-02
#
#
# Root relaxation: objective 2.082000e-02, 82 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0208200    0.02082  0.00%     -    3s
#
# Explored 1 nodes (82 simplex iterations) in 3.35 seconds (2.42 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.02082 23.7407
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.082000000053e-02, best bound 2.082000000031e-02, gap 0.0000%
#
#
#
#
#
# 0 80
# Set parameter LogFile to value "Error_Path80M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211779 rows, 77908 columns and 589904 nonzeros
# Model fingerprint: 0xeb25432b
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 8e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212283 by 1.000000000
#
# Presolve removed 210644 rows and 76417 columns
# Presolve time: 3.03s
# Presolved: 1135 rows, 1491 columns, 4945 nonzeros
# Variable types: 1299 continuous, 192 integer (192 binary)
# Found heuristic solution: objective 23.7211646
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.590e+03
#  Factor NZ  : 3.071e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.808e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.38491406e+03 -1.03984705e+04  1.06e+02 1.67e-01  2.54e+01     3s
#    1  -4.42138993e+01 -5.57919723e+03  4.28e+00 1.25e-01  3.00e+00     3s
#    2   6.72054244e+00 -5.69717375e+02  3.77e-01 2.94e-03  2.60e-01     3s
#    3   8.31553919e+00 -5.21676625e+01  1.62e-02 1.62e-04  2.48e-02     3s
#    4   2.46779729e+00 -1.29941344e+01  2.34e-04 1.34e-05  6.23e-03     3s
#    5   2.27415916e-01 -1.23091648e+00  4.99e-08 4.44e-16  5.87e-04     3s
#    6   4.05413698e-03 -5.70226502e-02  1.06e-11 2.22e-16  2.46e-05     3s
#    7   1.71201016e-04 -1.05243070e-03  6.42e-12 4.44e-16  4.93e-07     3s
#    8   6.46561915e-10 -1.74410271e-07  7.16e-12 2.22e-16  7.05e-11     3s
#
# Barrier solved model in 8 iterations and 3.23 seconds (2.39 work units)
# Optimal objective 6.46561915e-10
#
#
# Root relaxation: objective 4.618528e-13, 83 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    1   23.72116    0.00000   100%     -    3s
# H    0     0                       0.0000000    0.00000  0.00%     -    3s
#      0     0    0.00000    0    1    0.00000    0.00000  0.00%     -    3s
#
# Explored 1 nodes (83 simplex iterations) in 3.28 seconds (2.41 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 4.79616e-13 23.7212
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.684341886081e-13, best bound 4.796163466381e-13, gap 0.0000%
#
#
#
#
#
# 1 0
# Set parameter LogFile to value "Error_Path0M"
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 32400
# Set parameter Method to value 2
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0x2d5b9f07
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 2e+04]
# Presolve removed 210998 rows and 76728 columns
# Presolve time: 2.28s
# Presolved: 877 rows, 1180 columns, 4003 nonzeros
# Variable types: 1027 continuous, 153 integer (153 binary)
# Found heuristic solution: objective 65.5697854
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.633e+03
#  Factor NZ  : 2.108e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.020e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.13523019e+03 -7.25363010e+03  1.04e+02 1.68e-01  2.44e+01     2s
#    1   5.04410305e+00 -3.99117518e+03  4.42e+00 1.24e-01  2.83e+00     2s
#    2   5.12294623e+01 -4.04140391e+02  3.08e-01 2.78e-03  2.56e-01     2s
#    3   5.13202136e+01  2.79128431e+00  2.37e-02 1.51e-04  2.53e-02     2s
#    4   4.61130662e+01  3.87902849e+01  9.77e-05 4.44e-16  3.72e-03     2s
#    5   4.42229010e+01  4.18252635e+01  1.99e-05 4.44e-16  1.22e-03     2s
#    6   4.39745930e+01  4.28138103e+01  1.02e-05 2.39e-16  5.90e-04     2s
#    7   4.38514865e+01  4.32990247e+01  5.66e-06 2.22e-16  2.81e-04     2s
#    8   4.37569849e+01  4.35076113e+01  2.67e-06 2.22e-16  1.27e-04     2s
#    9   4.37325832e+01  4.35829753e+01  1.57e-06 2.22e-16  7.61e-05     2s
#   10   4.36933528e+01  4.36607983e+01  1.23e-07 4.44e-16  1.65e-05     2s
#   11   4.36863780e+01  4.36803475e+01  7.57e-11 2.22e-16  3.06e-06     2s
#   12   4.36859678e+01  4.36850227e+01  3.88e-11 4.44e-16  4.80e-07     2s
#   13   4.36859033e+01  4.36857306e+01  1.23e-10 2.22e-16  8.77e-08     2s
#   14   4.36859010e+01  4.36858955e+01  6.70e-11 2.22e-16  2.76e-09     2s
#   15   4.36858998e+01  4.36858998e+01  1.82e-10 4.44e-16  3.31e-12     2s
#
# Barrier solved model in 15 iterations and 2.42 seconds (1.77 work units)
# Optimal objective 4.36858998e+01
#
#
# Root relaxation: objective 4.368590e+01, 9 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   43.68590    0    3   65.56979   43.68590  33.4%     -    2s
# H    0     0                      43.6914769   43.68590  0.01%     -    2s
# H    0     0                      43.6860595   43.68590  0.00%     -    2s
# H    0     0                      43.6860464   43.68590  0.00%     -    2s
#      0     0   43.68597    0    1   43.68605   43.68597  0.00%     -    2s
#      0     0   43.68597    0    1   43.68605   43.68597  0.00%     -    2s
#      0     0   43.68597    0    2   43.68605   43.68597  0.00%     -    2s
#
# Explored 1 nodes (19 simplex iterations) in 2.66 seconds (1.89 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 43.686 43.6861 43.6915 65.5698
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.368604635777e+01, best bound 4.368604635777e+01, gap 0.0000%
#
#
#
#
#
# 1 10
# Set parameter LogFile to value "Error_Path10M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xf1e18aef
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 1e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R211888 by 4.000000000
#
# Presolve removed 210940 rows and 76665 columns
# Presolve time: 2.74s
# Presolved: 935 rows, 1243 columns, 4164 nonzeros
# Variable types: 1077 continuous, 166 integer (166 binary)
# Found heuristic solution: objective 44.9554845
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.479e+03
#  Factor NZ  : 2.221e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.108e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.13682613e+03 -5.38821616e+03  1.05e+02 8.25e-02  1.68e+01     3s
#    1  -1.47588013e+01 -2.89374602e+03  4.36e+00 8.30e-02  1.95e+00     3s
#    2   2.85068480e+01 -2.86654064e+02  3.71e-01 2.98e-03  1.75e-01     3s
#    3   2.86098091e+01 -1.67440173e+01  1.64e-02 3.12e-04  2.27e-02     3s
#    4   2.39899457e+01  1.27893249e+01  1.09e-03 4.50e-05  5.55e-03     3s
#    5   2.25511435e+01  2.07429166e+01  7.74e-05 1.63e-06  8.94e-04     3s
#    6   2.23785730e+01  2.18853161e+01  2.51e-05 2.22e-16  2.44e-04     3s
#    7   2.23183884e+01  2.20834748e+01  1.10e-05 2.22e-16  1.16e-04     3s
#    8   2.22931828e+01  2.22236259e+01  6.14e-06 2.22e-16  3.44e-05     3s
#    9   2.22771564e+01  2.22498962e+01  1.68e-06 2.22e-16  1.35e-05     3s
#   10   2.22698594e+01  2.22650762e+01  2.89e-07 2.22e-16  2.36e-06     3s
#   11   2.22684715e+01  2.22677882e+01  2.45e-09 2.22e-16  3.37e-07     3s
#   12   2.22683411e+01  2.22682966e+01  9.53e-11 2.22e-16  2.19e-08     3s
#   13   2.22683356e+01  2.22683351e+01  6.76e-09 4.44e-16  2.59e-10     3s
#   14   2.22683355e+01  2.22683355e+01  3.78e-12 2.22e-16  2.59e-13     3s
#
# Barrier solved model in 14 iterations and 2.95 seconds (2.09 work units)
# Optimal objective 2.22683355e+01
#
#
# Root relaxation: objective 2.226834e+01, 6 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   22.26834    0    3   44.95548   22.26834  50.5%     -    2s
# H    0     0                      22.2940664   22.26834  0.12%     -    2s
# H    0     0                      22.2684523   22.26834  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (6 simplex iterations) in 3.01 seconds (2.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 22.2685 22.2941 44.9555
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.226845231740e+01, best bound 2.226845231740e+01, gap 0.0000%
#
#
#
#
#
# 1 20
# Set parameter LogFile to value "Error_Path20M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xd7522c29
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 2e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R211948 by 7.000000000
#
# Presolve removed 210893 rows and 76613 columns
# Presolve time: 2.61s
# Presolved: 982 rows, 1295 columns, 4335 nonzeros
# Variable types: 1117 continuous, 178 integer (178 binary)
# Found heuristic solution: objective 37.4257089
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.690e+03
#  Factor NZ  : 2.419e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.338e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.10861141e+03 -5.53171622e+03  1.05e+02 8.31e-02  1.67e+01     3s
#    1  -1.65157967e+01 -2.98151759e+03  3.94e+00 8.30e-02  1.90e+00     3s
#    2   1.97046575e+01 -2.89603281e+02  4.77e-01 3.03e-03  1.71e-01     3s
#    3   2.11828339e+01 -1.92945864e+01  4.42e-02 1.63e-04  2.03e-02     3s
#    4   1.60090886e+01  9.61191963e+00  6.15e-04 1.04e-14  3.06e-03     3s
#    5   1.45127026e+01  1.30474327e+01  1.35e-05 2.66e-15  7.00e-04     3s
#    6   1.44577636e+01  1.42622378e+01  4.94e-06 2.22e-16  9.34e-05     3s
#    7   1.44207689e+01  1.44040199e+01  2.84e-07 4.44e-16  8.00e-06     3s
#    8   1.44189200e+01  1.44188862e+01  2.22e-11 2.22e-16  1.61e-08     3s
#    9   1.44189150e+01  1.44189150e+01  1.13e-11 2.22e-16  1.65e-14     3s
#
# Barrier solved model in 9 iterations and 2.81 seconds (2.02 work units)
# Optimal objective 1.44189150e+01
#
#
# Root relaxation: objective 1.441892e+01, 74 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   14.41892    0    2   37.42571   14.41892  61.5%     -    2s
# H    0     0                      14.4189150   14.41892  0.00%     -    2s
#      0     0   14.41892    0    2   14.41892   14.41892  0.00%     -    2s
#
# Explored 1 nodes (74 simplex iterations) in 2.86 seconds (2.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 14.4189 37.4257
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.441891500692e+01, best bound 1.441891500692e+01, gap 0.0000%
#
#
#
#
#
# 1 30
# Set parameter LogFile to value "Error_Path30M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0x63f2b571
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 3e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212020 by 1.000000000
#
# Presolve removed 210868 rows and 76581 columns
# Presolve time: 2.51s
# Presolved: 1007 rows, 1327 columns, 4436 nonzeros
# Variable types: 1148 continuous, 179 integer (179 binary)
# Found heuristic solution: objective 31.8500977
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.834e+03
#  Factor NZ  : 2.553e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.427e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.14846568e+03 -5.64399430e+03  1.05e+02 8.33e-02  1.67e+01     3s
#    1  -2.34037181e+01 -3.07554968e+03  3.94e+00 8.31e-02  1.90e+00     3s
#    2   1.39427138e+01 -3.06974383e+02  4.75e-01 3.09e-03  1.72e-01     3s
#    3   1.54829448e+01 -2.52457743e+01  4.37e-02 1.55e-04  1.98e-02     3s
#    4   1.01149289e+01  4.88181809e+00  4.22e-05 2.58e-14  2.42e-03     3s
#    5   8.76956738e+00  7.79881580e+00  4.71e-06 4.44e-15  4.50e-04     3s
#    6   8.59601561e+00  8.56519311e+00  2.81e-08 2.22e-16  1.43e-05     3s
#    7   8.59331979e+00  8.59319303e+00  8.22e-11 2.22e-16  5.87e-08     3s
#    8   8.59329813e+00  8.59329812e+00  5.60e-12 2.22e-16  1.11e-13     3s
#
# Barrier solved model in 8 iterations and 2.71 seconds (2.04 work units)
# Optimal objective 8.59329813e+00
#
#
# Root relaxation: objective 8.593298e+00, 75 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    8.59330    0    2   31.85010    8.59330  73.0%     -    2s
# H    0     0                       8.5932981    8.59330  0.00%     -    2s
#      0     0    8.59330    0    2    8.59330    8.59330  0.00%     -    2s
#
# Explored 1 nodes (75 simplex iterations) in 2.76 seconds (2.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 8.5933 31.8501
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.593298125001e+00, best bound 8.593298125001e+00, gap 0.0000%
#
#
#
#
#
# 1 40
# Set parameter LogFile to value "Error_Path40M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0x99c5f1ed
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 4e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212092 by 1.000000000
#
# Presolve removed 210844 rows and 76553 columns
# Presolve time: 2.45s
# Presolved: 1031 rows, 1355 columns, 4517 nonzeros
# Variable types: 1171 continuous, 184 integer (184 binary)
# Found heuristic solution: objective 28.4504877
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.895e+03
#  Factor NZ  : 2.709e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.601e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.14856925e+03 -5.75289052e+03  1.05e+02 8.35e-02  1.67e+01     3s
#    1  -2.77903249e+01 -3.13981948e+03  4.01e+00 8.31e-02  1.91e+00     3s
#    2   1.01122059e+01 -3.73634791e+02  4.98e-01 2.62e-03  2.01e-01     3s
#    3   1.20064113e+01 -5.80858327e+01  4.95e-02 2.93e-04  3.32e-02     3s
#    4   7.40346576e+00 -1.57055807e+00  1.14e-03 1.11e-15  4.11e-03     3s
#    5   5.08505336e+00  4.60282419e+00  1.01e-05 2.22e-16  2.20e-04     3s
#    6   5.00158204e+00  4.99005470e+00  2.39e-11 4.44e-16  5.25e-06     3s
#    7   5.00083359e+00  5.00076256e+00  2.40e-11 4.44e-16  3.24e-08     3s
#    8   5.00082563e+00  5.00082562e+00  6.55e-12 4.44e-16  3.61e-14     3s
#
# Barrier solved model in 8 iterations and 2.65 seconds (2.00 work units)
# Optimal objective 5.00082563e+00
#
#
# Root relaxation: objective 5.000826e+00, 76 iterations, 0.06 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.0008256    5.00083  0.00%     -    2s
#
# Explored 1 nodes (76 simplex iterations) in 2.69 seconds (2.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 5.00083 28.4505
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.000825625001e+00, best bound 5.000825625001e+00, gap 0.0000%
#
#
#
#
#
# 1 50
# Set parameter LogFile to value "Error_Path50M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xfc64c168
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 5e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212167 by 1.000000000
#
# Presolve removed 210809 rows and 76508 columns
# Presolve time: 2.52s
# Presolved: 1066 rows, 1400 columns, 4647 nonzeros
# Variable types: 1214 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 25.9818989
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.038e+03
#  Factor NZ  : 2.833e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.725e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.40530168e+02 -6.08161767e+03  6.51e+01 8.35e-02  1.14e+01     3s
#    1  -2.25558516e+01 -2.26617393e+03  3.19e+00 5.19e-02  1.34e+00     3s
#    2   9.20487004e+00 -2.37779592e+02  3.18e-01 1.35e-03  1.22e-01     3s
#    3   8.62212243e+00 -3.06606869e+01  1.52e-02 9.52e-05  1.75e-02     3s
#    4   3.57999690e+00 -1.54368003e+00  1.30e-05 2.22e-16  2.25e-03     3s
#    5   2.41215267e+00  2.14435061e+00  1.85e-07 2.22e-16  1.18e-04     3s
#    6   2.38126320e+00  2.37943844e+00  1.41e-11 4.44e-16  8.01e-07     3s
#    7   2.38104276e+00  2.38104079e+00  7.04e-12 2.22e-16  8.65e-10     3s
#    8   2.38104250e+00  2.38104250e+00  4.04e-12 2.22e-16  8.65e-16     3s
#
# Barrier solved model in 8 iterations and 2.73 seconds (2.05 work units)
# Optimal objective 2.38104250e+00
#
#
# Root relaxation: objective 2.381043e+00, 77 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.38104    0    1   25.98190    2.38104  90.8%     -    2s
# H    0     0                       2.3810425    2.38104  0.00%     -    2s
#      0     0    2.38104    0    1    2.38104    2.38104  0.00%     -    2s
#
# Explored 1 nodes (77 simplex iterations) in 2.78 seconds (2.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 2.38104 25.9819
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.381042500001e+00, best bound 2.381042500001e+00, gap 0.0000%
#
#
#
#
#
# 1 60
# Set parameter LogFile to value "Error_Path60M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xa310e67e
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 6e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212236 by 2.000000000
#
# Presolve removed 210791 rows and 76482 columns
# Presolve time: 2.66s
# Presolved: 1084 rows, 1426 columns, 4719 nonzeros
# Variable types: 1240 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 24.2894358
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.111e+03
#  Factor NZ  : 2.824e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.650e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.49094852e+02 -6.24015960e+03  6.51e+01 8.35e-02  1.14e+01     3s
#    1  -2.16635621e+01 -2.32624168e+03  2.95e+00 5.19e-02  1.31e+00     3s
#    2   7.90368900e+00 -2.32656470e+02  2.87e-01 1.25e-03  1.16e-01     3s
#    3   6.88608863e+00 -3.13939677e+01  9.50e-03 8.40e-05  1.66e-02     3s
#    4   1.83241868e+00 -3.46373387e+00  7.31e-06 2.22e-15  2.27e-03     3s
#    5   6.32386108e-01  3.65151590e-01  9.21e-08 2.78e-16  1.15e-04     3s
#    6   6.04483604e-01  6.01382497e-01  1.19e-11 2.22e-16  1.33e-06     3s
#    7   6.04275533e-01  6.04271933e-01  6.67e-12 2.22e-16  1.55e-09     3s
#    8   6.04275000e-01  6.04275000e-01  5.70e-12 2.22e-16  1.55e-15     3s
#
# Barrier solved model in 8 iterations and 2.87 seconds (2.15 work units)
# Optimal objective 6.04275000e-01
#
#
# Restart crossover...
#
#
# Root relaxation: objective 6.042750e-01, 77 iterations, 0.06 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.60428    0    1   24.28944    0.60428  97.5%     -    2s
# H    0     0                       0.6042750    0.60428  0.00%     -    2s
#      0     0    0.60428    0    1    0.60428    0.60428  0.00%     -    2s
#
# Explored 1 nodes (77 simplex iterations) in 2.92 seconds (2.16 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.604275 24.2894
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 6.042750000004e-01, best bound 6.042750000004e-01, gap 0.0000%
#
#
#
#
#
# 1 70
# Set parameter LogFile to value "Error_Path70M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0x9bcb26fe
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 7e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212310 by 3.000000000
#
# Presolve removed 210773 rows and 76451 columns
# Presolve time: 3.09s
# Presolved: 1102 rows, 1457 columns, 4839 nonzeros
# Variable types: 1271 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 23.7406833
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.493e+03
#  Factor NZ  : 3.035e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.829e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# ...
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 3e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212020 by 1.000000000
#
# Presolve removed 210868 rows and 76581 columns
# Presolve time: 2.72s
# Presolved: 1007 rows, 1327 columns, 4437 nonzeros
# Variable types: 1148 continuous, 179 integer (179 binary)
# Found heuristic solution: objective 31.9163802
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.835e+03
#  Factor NZ  : 2.553e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.427e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.13095874e+03 -5.64406583e+03  1.05e+02 8.33e-02  1.67e+01     3s
#    1  -2.26870922e+01 -3.07562488e+03  3.94e+00 8.31e-02  1.90e+00     3s
#    2   1.40775122e+01 -3.06942541e+02  4.75e-01 3.09e-03  1.72e-01     3s
#    3   1.55418741e+01 -2.51897156e+01  4.37e-02 1.55e-04  1.98e-02     3s
#    4   1.01559333e+01  4.92003370e+00  4.08e-05 1.33e-15  2.43e-03     3s
#    5   8.81246758e+00  7.82077179e+00  4.59e-06 2.22e-16  4.59e-04     3s
#    6   8.63706424e+00  8.59954219e+00  2.91e-08 2.22e-16  1.74e-05     3s
#    7   8.63437580e+00  8.63419809e+00  1.26e-10 2.22e-16  8.23e-08     3s
#    8   8.63434688e+00  8.63434687e+00  7.91e-12 4.44e-16  3.05e-13     3s
#
# Barrier solved model in 8 iterations and 2.93 seconds (2.09 work units)
# Optimal objective 8.63434688e+00
#
#
# Root relaxation: objective 8.634347e+00, 75 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    8.63435    0    1   31.91638    8.63435  72.9%     -    2s
# H    0     0                       8.6343469    8.63435  0.00%     -    2s
#      0     0    8.63435    0    1    8.63435    8.63435  0.00%     -    2s
#
# Explored 1 nodes (75 simplex iterations) in 2.98 seconds (2.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 8.63435 31.9164
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.634346875001e+00, best bound 8.634346875001e+00, gap 0.0000%
#
#
#
#
#
# 49 40
# Set parameter LogFile to value "Error_Path40M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xa1f23629
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 4e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212092 by 1.000000000
#
# Presolve removed 210844 rows and 76553 columns
# Presolve time: 2.62s
# Presolved: 1031 rows, 1355 columns, 4517 nonzeros
# Variable types: 1171 continuous, 184 integer (184 binary)
# Found heuristic solution: objective 28.5889033
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.895e+03
#  Factor NZ  : 2.709e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.601e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.18717959e+02 -5.78763879e+03  6.50e+01 8.35e-02  1.14e+01     3s
#    1  -1.90305467e+01 -2.16145363e+03  3.19e+00 5.22e-02  1.33e+00     3s
#    2   1.20101238e+01 -2.25976717e+02  3.16e-01 1.37e-03  1.23e-01     3s
#    3   1.10614699e+01 -2.89478085e+01  1.56e-02 1.32e-04  1.85e-02     3s
#    4   6.34473430e+00  1.24860714e+00  3.05e-05 4.88e-15  2.32e-03     3s
#    5   5.15741844e+00  4.85001757e+00  4.06e-07 2.22e-16  1.40e-04     3s
#    6   5.12422673e+00  5.12209323e+00  2.15e-11 2.22e-16  9.72e-07     3s
#    7   5.12397354e+00  5.12397036e+00  6.81e-12 2.22e-16  1.45e-09     3s
#    8   5.12397313e+00  5.12397312e+00  6.23e-12 4.44e-16  1.46e-15     3s
#
# Barrier solved model in 8 iterations and 2.81 seconds (1.99 work units)
# Optimal objective 5.12397313e+00
#
#
# Root relaxation: objective 5.123973e+00, 76 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.12397    0    1   28.58890    5.12397  82.1%     -    2s
# H    0     0                       5.1239731    5.12397  0.00%     -    2s
#      0     0    5.12397    0    1    5.12397    5.12397  0.00%     -    2s
#
# Explored 1 nodes (76 simplex iterations) in 2.86 seconds (2.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 5.12397 28.5889
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.123973125001e+00, best bound 5.123973125001e+00, gap 0.0000%
#
#
#
#
#
# 49 50
# Set parameter LogFile to value "Error_Path50M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0x93021af9
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 5e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212167 by 1.000000000
#
# Presolve removed 210809 rows and 76508 columns
# Presolve time: 2.75s
# Presolved: 1066 rows, 1400 columns, 4647 nonzeros
# Variable types: 1214 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 26.1706996
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.038e+03
#  Factor NZ  : 2.833e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.725e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.45766461e+02 -6.08143665e+03  6.51e+01 8.35e-02  1.14e+01     3s
#    1  -2.26327419e+01 -2.26598479e+03  3.19e+00 5.19e-02  1.34e+00     3s
#    2   9.36718012e+00 -2.37583457e+02  3.18e-01 1.35e-03  1.22e-01     3s
#    3   8.80964847e+00 -3.04714808e+01  1.52e-02 9.52e-05  1.75e-02     3s
#    4   3.76880674e+00 -1.35490568e+00  1.30e-05 4.44e-16  2.25e-03     3s
#    5   2.60095265e+00  2.33315481e+00  1.85e-07 2.22e-16  1.18e-04     3s
#    6   2.57006383e+00  2.56823908e+00  1.27e-11 2.22e-16  8.01e-07     3s
#    7   2.56984339e+00  2.56984142e+00  4.84e-12 2.22e-16  8.65e-10     3s
#    8   2.56984313e+00  2.56984312e+00  6.25e-12 2.22e-16  8.65e-16     3s
#
# Barrier solved model in 8 iterations and 2.96 seconds (2.08 work units)
# Optimal objective 2.56984313e+00
#
#
# Root relaxation: objective 2.569843e+00, 77 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.56984    0    1   26.17070    2.56984  90.2%     -    2s
# H    0     0                       2.5698431    2.56984  0.00%     -    2s
#      0     0    2.56984    0    1    2.56984    2.56984  0.00%     -    2s
#
# Explored 1 nodes (77 simplex iterations) in 3.00 seconds (2.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 2.56984 26.1707
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.569843125001e+00, best bound 2.569843125001e+00, gap 0.0000%
#
#
#
#
#
# 49 60
# Set parameter LogFile to value "Error_Path60M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xd0e7485a
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 6e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212236 by 2.000000000
#
# Presolve removed 210789 rows and 76480 columns
# Presolve time: 2.94s
# Presolved: 1086 rows, 1428 columns, 4742 nonzeros
# Variable types: 1242 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 24.2945658
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.397e+03
#  Factor NZ  : 2.801e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.578e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.34325933e+03 -9.61577795e+03  1.05e+02 1.67e-01  2.52e+01     3s
#    1  -4.21816267e+01 -5.25412565e+03  4.25e+00 1.25e-01  2.96e+00     3s
#    2   7.15740552e+00 -5.59196352e+02  3.93e-01 2.47e-03  2.68e-01     3s
#    3   8.90708972e+00 -5.03448742e+01  1.75e-02 1.27e-04  2.53e-02     3s
#    4   3.06790209e+00 -1.19772575e+01  2.14e-04 6.50e-06  6.33e-03     3s
#    5   8.18336433e-01 -5.03167927e-01  3.90e-08 4.44e-16  5.55e-04     3s
#    6   6.11802526e-01  5.64738947e-01  1.22e-11 4.16e-16  1.98e-05     3s
#    7   6.09478313e-01  6.08796476e-01  9.71e-12 2.22e-16  2.86e-07     3s
#    8   6.09405001e-01  6.09404822e-01  8.13e-12 2.22e-16  7.53e-11     3s
#
# Barrier solved model in 8 iterations and 3.15 seconds (2.23 work units)
# Optimal objective 6.09405001e-01
#
#
# Root relaxation: objective 6.094050e-01, 83 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.6094050    0.60941  0.00%     -    3s
#
# Explored 1 nodes (83 simplex iterations) in 3.19 seconds (2.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.609405 24.2946
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 6.094050000004e-01, best bound 6.094050000004e-01, gap 0.0000%
#
#
#
#
#
# 49 70
# Set parameter LogFile to value "Error_Path70M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0x0528d930
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 7e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212310 by 3.000000000
#
# Presolve removed 210773 rows and 76451 columns
# Presolve time: 3.26s
# Presolved: 1102 rows, 1457 columns, 4839 nonzeros
# Variable types: 1271 continuous, 186 integer (186 binary)
# Found heuristic solution: objective 23.7406833
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.493e+03
#  Factor NZ  : 3.035e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.829e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.38526147e+03 -9.90854572e+03  1.05e+02 1.67e-01  2.52e+01     3s
#    1  -4.42362355e+01 -5.37614530e+03  4.26e+00 1.25e-01  2.95e+00     3s
#    2   6.67336063e+00 -5.57760719e+02  3.82e-01 3.14e-03  2.61e-01     3s
#    3   8.36498088e+00 -5.47992304e+01  1.81e-02 1.83e-04  2.64e-02     3s
#    4   2.56755805e+00 -1.32258232e+01  1.84e-04 1.60e-05  6.48e-03     3s
#    5   2.59528917e-01 -1.14795070e+00  3.33e-08 4.44e-16  5.77e-04     3s
#    6   2.38749508e-02 -7.28734541e-03  1.72e-10 2.22e-16  1.28e-05     3s
#    7   2.08592473e-02  2.04373103e-02  1.58e-11 4.44e-16  1.73e-07     3s
#    8   2.08200000e-02  2.08199988e-02  5.42e-12 2.22e-16  5.20e-13     3s
#
# Barrier solved model in 8 iterations and 3.47 seconds (2.44 work units)
# Optimal objective 2.08200000e-02
#
#
# Root relaxation: objective 2.082000e-02, 82 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0208200    0.02082  0.00%     -    3s
#
# Explored 1 nodes (82 simplex iterations) in 3.50 seconds (2.45 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.02082 23.7407
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.082000000053e-02, best bound 2.082000000036e-02, gap 0.0000%
#
#
#
#
#
# 49 80
# Set parameter LogFile to value "Error_Path80M"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: AMD EPYC 7763 64-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211875 rows, 77908 columns and 590192 nonzeros
# Model fingerprint: 0xd157caf1
# Variable types: 55968 continuous, 21940 integer (21578 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+05]
#   Objective range  [6e-02, 6e-02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e-02, 8e+07]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R212379 by 1.000000000
#
# Presolve removed 210733 rows and 76410 columns
# Presolve time: 3.13s
# Presolved: 1142 rows, 1498 columns, 4962 nonzeros
# Variable types: 1300 continuous, 198 integer (198 binary)
# Found heuristic solution: objective 23.7211646
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.430e+03
#  Factor NZ  : 3.196e+04 (roughly 1 MB of memory)
#  Factor Ops : 2.021e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.13913418e+03 -6.10621667e+03  1.04e+02 8.34e-02  1.56e+01     3s
#    1  -2.84027678e+01 -3.32035940e+03  3.69e+00 7.77e-02  1.77e+00     3s
#    2   4.20783651e+00 -3.50104887e+02  5.87e-01 3.43e-03  1.72e-01     3s
#    3   7.07181145e+00 -4.43300514e+01  1.62e-02 2.19e-04  2.15e-02     3s
#    4   1.68042149e+00 -4.63418918e+00  1.80e-04 2.44e-15  2.60e-03     3s
#    5   2.60468559e-02 -2.14665245e-01  1.18e-06 2.22e-16  9.91e-05     3s
#    6   2.11162199e-04 -8.75032603e-03  6.01e-12 4.44e-16  3.69e-06     3s
#    7   2.26496066e-06 -1.30586932e-05  7.43e-12 2.22e-16  6.31e-09     3s
#    8   2.82796009e-12 -1.25446320e-11  2.29e-12 2.22e-16  6.33e-15     3s
#
# Barrier solved model in 8 iterations and 3.33 seconds (2.36 work units)
# Optimal objective 2.82796009e-12
#
#
# Root relaxation: objective 5.435652e-13, 79 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    3s
#
# Explored 1 nodes (79 simplex iterations) in 3.37 seconds (2.37 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 5.61329e-13 23.7212
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.684341886081e-13, best bound 5.613287612505e-13, gap 0.0000%

# %%
objective_value = pd.DataFrame(objective_value)
objective_value.to_csv("norta_out_of_sample_testing.csv")

# %%
objective_value.plot(le)
# Out:
# <AxesSubplot:>
